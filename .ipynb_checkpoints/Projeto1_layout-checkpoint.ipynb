# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Gabriela Moreno Boriero

# %% [markdown]
# ## Pergunta (s) a ser respondida

# %% [markdown]
# 1- Desde que o Uruguai entrou no Mercosul houve aumento na porcentagem das exportações em relação ao PIB?
# 2- Qual a relação das exportações do Uruguay com: os outros países do bloco; o resto do mundo e países similares a Uruguai?

# %% [markdown]
# ## Explicação da hipótese e mecanismo

# %% [markdown]
# O Mercosul é um bloco economico formado por Uruguai, Argentina, Brasil e Paraguai. Este tem como objetivo integrar os países tanto economicamente quanto aos habitantes.Assim, por meio da tarifa externa comum (TEC) os países do bloco possuem mais competetitividade, dessa forma possibilitando um aumento no numero de exportações.
# https://www.significados.com.br/mercosul/

# %% [markdown]
# ## Bases de dados usadas

# %% [markdown]
# https://www.gapminder.org/data/
#
# Variaveis:
# * Exports(/% of GDP)
# * GDP

# %% [markdown]
# ## Análise de dados

# %% [markdown]
# Insira abaixo uma análise de dados tratada para ter maior clareza.
#
# Lembre-se de que, além deste arquivo principal, você precisa entregar um ou mais *notebooks* mais brutos com todas as tentativas que fez e que não deram certo .
#
# **Não inclua dados ou gráficos sem motivação nem interpretação** - sempre que fizer uma análise, plot ou tablea, diga qual sua intenção. Logo após a apresentação diga qual conclusão específica ou interpretação você tira daquela análise

# %%
#import
# %matplotlib inline
import pandas as pd
import seaborn as sns
import math as math
from scipy import stats
import matplotlib.pyplot as plt

# %%
#leitura dos arquivos em Excel
exportacao = pd.read_excel('exports_percent_of_gdp.xlsx')
pib = pd.read_excel('gdp_total_yearly_growth.xlsx')

# %%
#mudando o índice das tabelas
exportacao_indice = exportacao.set_index("country")
pib_indice = exportacao.set_index("country")

# %%
#tabela do Uruguai
#será usada para dividir entre ANTES e DEPOIS de entrar no MERCOSUL 
exportacao_Uruguay = exportacao_indice.loc['Uruguay',:]

# %% [markdown]
# As tabelas de ANTES e DEPOIS da entrada no Mercosul será utilizada para formar 2 retas e por meio da regressão descobrir qual a diferença de inclinação entre as retas:

# %%
#tabela do Uruguai ANTES de entrar no mercosul 
antes=exportacao_Uruguay.transpose()
uruguay_anterior=antes[(antes.index>1960) & (antes.index<1990)]
uruguay_anterior
# Out:
# 1961    142.0
# 1962    113.0
# 1963    120.0
# 1964    119.0
# 1965    184.0
# 1966    171.0
# 1967    146.0
# 1968    152.0
# 1969    134.0
# 1970    139.0
# 1971    103.0
# 1972    154.0
# 1973    104.0
# 1974    144.0
# 1975    168.0
# 1976    196.0
# 1977    199.0
# 1978    188.0
# 1979    168.0
# 1980    150.0
# 1981    152.0
# 1982    143.0
# 1983    257.0
# 1984    266.0
# 1985    268.0
# 1986    262.0
# 1987    216.0
# 1988    221.0
# 1989    235.0
# Name: Uruguay, dtype: float64

# %%
plt.figure(figsize=(30,10))
plt.plot(uruguay_anterior.index,uruguay_anterior)
plt.title('Exportação Uruguay antes entrada no Mercosul')
plt.xlabel('Ano')
plt.ylabel('Exportação Uruguay ')
# Out:
# Text(0, 0.5, 'Exportação Uruguay ')

# %%
média_uruguay_antes=uruguay_anterior.mean()
média_uruguay_antes
# Out:
# 172.89655172413794

# %%
#tabela do Uruguai DEPOIS de entrar no mercosul 
depois=exportacao_Uruguay.transpose()
uruguay_depois=depois[(depois.index>1990)]
uruguay_depois
# Out:
# 1991    207.0
# 1992    204.0
# 1993    191.0
# 1994    198.0
# 1995    190.0
# 1996    197.0
# 1997    175.0
# 1998    164.0
# 1999    151.0
# 2000    167.0
# 2001    168.0
# 2002    206.0
# 2003    274.0
# 2004    321.0
# 2005    304.0
# 2006    303.0
# 2007    291.0
# 2008    302.0
# 2009    271.0
# 2010    263.0
# 2011    264.0
# 2012    259.0
# 2013    234.0
# 2014    235.0
# 2015    225.0
# 2016    214.0
# 2017    216.0
# Name: Uruguay, dtype: float64

# %%
plt.figure(figsize=(30,10))
plt.plot(uruguay_depois.index,uruguay_depois)
plt.title('Exportação Uruguay depois entrada no Mercosul')
plt.xlabel('Ano')
plt.ylabel('Exportação Uruguay ')
# Out:
# Text(0, 0.5, 'Exportação Uruguay ')

# %%
média_uruguay_depois=uruguay_depois.mean()
média_uruguay_depois
# Out:
# 229.40740740740742

# %%
data = {
'Época': ['Antes', 'Depois'],
'Média': [média_uruguay_antes,média_uruguay_depois],
}
tabela_media_uruguay = pd.DataFrame(data, columns=['Época', 'Média'])

# %%
plot = tabela_media_uruguay.plot(kind='bar',title='Exportação Uruguay',figsize=(6, 6),color=('b','g'))
plt.ylabel('Exportação Uruguay (em % do Pib)')
plt.xlabel('Antes X Depois')
plt.show()

# %%
plt.scatter(uruguay_depois.index,uruguay_depois, color="r")
plt.scatter(uruguay_anterior.index, uruguay_anterior, color="b")
plt.title('Exportação Uruguay antes e depois entrada no Mercosul')
plt.xlabel('Ano')
plt.ylabel('Exportação Uruguay ')
# Out:
# Text(0, 0.5, 'Exportação Uruguay ')

# %%
def reta(dados_x, dados_y, c):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()

    print('Ajuste linear entre:')
    print('Coeficiente linear:', b)
    print('Coeficiente angular:', a)
    plt.scatter(dados_x, dados_y, c=c, alpha=0.8)
    plt.title('Retas Uruguay antes e depois da entrada no Mercosul')
    plt.xlabel('Anos')
    plt.ylabel('exportação(% do Pib)')

    plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color=c)

    plt.tight_layout()

# %%
plt.scatter(uruguay_anterior.index, uruguay_anterior, color="b")
reta(uruguay_anterior.index, uruguay_anterior, "pink")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-c101f7920e02> in <module>
#       1 plt.scatter(uruguay_anterior.index, uruguay_anterior, color="b")
# ----> 2 reta(uruguay_anterior.index, uruguay_anterior, "pink")
#
# <ipython-input-14-a230e59438e2> in reta(dados_x, dados_y, c)
#       1 def reta(dados_x, dados_y, c):
# ----> 2     a = dados_y.cov(dados_x) / dados_x.var()
#       3     b = dados_y.mean() - a*dados_x.mean()
#       4
#       5     print('Ajuste linear entre:')
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in cov(self, other, min_periods)
#    2125         Normalized by N-1 (unbiased estimator).
#    2126         """
# -> 2127         this, other = self.align(other, join='inner', copy=False)
#    2128         if len(this) == 0:
#    2129             return np.nan
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    3662                                          fill_value=fill_value, method=method,
#    3663                                          limit=limit, fill_axis=fill_axis,
# -> 3664                                          broadcast_axis=broadcast_axis)
#    3665
#    3666     def rename(self, index=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    8428                                       fill_axis=fill_axis)
#    8429         else:  # pragma: no cover
# -> 8430             raise TypeError('unsupported type: %s' % type(other))
#    8431
#    8432     def _align_frame(self, other, join='outer', axis=None, level=None,
#
# TypeError: unsupported type: <class 'pandas.core.indexes.base.Index'>

# %% [markdown]
# Separar os valores do mercosul para realizar um grafico com dois indices e plotar 3 linhas (mercosul, outros países e paises semelhantes aos do mercosul)

# %%
#tabela do Mercosul
paises_no_mercosul=exportacao_indice.transpose()
MERCOSUL_1990 = paises_no_mercosul[(paises_no_mercosul.index>1990)]
exportacao_paises_Mercosul = MERCOSUL_1990.loc[:,["Uruguay","Argentina","Brazil","Paraguay"]]
exportacao_paises_Mercosul
# Out:
# country  Uruguay  Argentina  Brazil  Paraguay
# 1991       207.0       7.68    8.68      50.8
# 1992       204.0       6.60   10.90      49.8
# 1993       191.0       6.91   10.50      59.9
# 1994       198.0       7.53    9.67      60.8
# 1995       190.0       9.68    7.53      61.8
# 1996       197.0      10.40    6.73      52.7
# 1997       175.0      10.60    6.98      48.5
# 1998       164.0      10.40    7.03      56.3
# 1999       151.0       9.83    9.56      45.3
# 2000       167.0      11.00   10.20      46.8
# 2001       168.0      11.60   12.40      45.1
# 2002       206.0      28.40   14.20      53.8
# 2003       274.0      25.90   15.20      55.0
# 2004       321.0      23.80   16.50      54.4
# 2005       304.0      23.20   15.20      58.2
# 2006       303.0      23.00   14.40      58.7
# 2007       291.0      22.70   13.30      56.7
# 2008       302.0      22.10   13.50      54.0
# 2009       271.0      19.60   10.90      51.5
# 2010       263.0      18.90   10.70      55.1
# 2011       264.0      18.40   11.50      52.5
# 2012       259.0      16.20   11.70      49.9
# 2013       234.0      14.60   11.60      49.6
# 2014       235.0      14.40   11.00      45.2
# 2015       225.0      10.70   12.90      42.3
# 2016       214.0      12.60   12.50      41.7
# 2017       216.0      11.20   12.60      41.8

# %%
#fazendo a média dos paises do mercosul a cada ano 
exportacao_paises_Mercosul_transposta=exportacao_paises_Mercosul.transpose()
média_paises_mercosul_ano=exportacao_paises_Mercosul_transposta.describe()
média_paises_mercosul_ano
# Out:
#              1991        1992        1993        1994       1995        1996  \
# count    4.000000    4.000000    4.000000    4.000000    4.00000    4.000000
# mean    68.540000   67.825000   67.077500   69.000000   67.25250   66.707500
# std     94.468757   92.839445   86.080281   89.455482   85.59215   89.331183
# min      7.680000    6.600000    6.910000    7.530000    7.53000    6.730000
# 25%      8.430000    9.825000    9.602500    9.135000    9.14250    9.482500
# 50%     29.740000   30.350000   35.200000   35.235000   35.74000   31.550000
# 75%     89.850000   88.350000   92.675000   95.100000   93.85000   88.775000
# max    207.000000  204.000000  191.000000  198.000000  190.00000  197.000000
#
#              1997        1998        1999        2000  ...        2008  \
# count    4.000000    4.000000    4.000000    4.000000  ...    4.000000
# mean    60.270000   59.432500   53.922500   58.750000  ...   97.900000
# std     78.757939   73.244756   66.859476   74.157557  ...  137.177525
# min      6.980000    7.030000    9.560000   10.200000  ...   13.500000
# 25%      9.695000    9.557500    9.762500   10.800000  ...   19.950000
# 50%     29.550000   33.350000   27.565000   28.900000  ...   38.050000
# 75%     80.125000   83.225000   71.725000   76.850000  ...  116.000000
# max    175.000000  164.000000  151.000000  167.000000  ...  302.000000
#
#              2009        2010        2011        2012        2013        2014  \
# count    4.000000    4.000000    4.000000    4.000000    4.000000    4.000000
# mean    88.250000   86.925000   86.600000   84.200000   77.450000   76.400000
# std    123.077171  118.957818  119.617195  117.773483  105.782592  106.846557
# min     10.900000   10.700000   11.500000   11.700000   11.600000   11.000000
# 25%     17.425000   16.850000   16.675000   15.075000   13.850000   13.550000
# 50%     35.550000   37.000000   35.450000   33.050000   32.100000   29.800000
# 75%    106.375000  107.075000  105.375000  102.175000   95.700000   92.650000
# max    271.000000  263.000000  264.000000  259.000000  234.000000  235.000000
#
#              2015        2016        2017
# count    4.000000    4.000000    4.000000
# mean    72.725000   70.200000   70.400000
# std    102.533714   96.846511   98.086357
# min     10.700000   12.500000   11.200000
# 25%     12.350000   12.575000   12.250000
# 50%     27.600000   27.150000   27.200000
# 75%     87.975000   84.775000   85.350000
# max    225.000000  214.000000  216.000000
#
# [8 rows x 27 columns]

# %%
#calculando média de exportaçao dos paises pertencentes ao bloco desde a criação do bloco (1991)
média_paises_mercosul= média_paises_mercosul_ano.loc["mean",:]
média_total_países_mercosul=média_paises_mercosul.mean()
média_total_países_mercosul
# Out:
# 76.92601851851852

# %%
plt.figure(figsize=(30,10))
plt.plot(exportacao_paises_Mercosul.index ,média_paises_mercosul)
plt.title('Dados Exportação paises mercosul')
plt.xlabel('Ano')
plt.ylabel('Média exportação dos países do Mercosul')
# Out:
# Text(0, 0.5, 'Média exportação dos países do Mercosul')

# %%
data = {
'País/Organização': ['Uruguay', 'Mercosul'],
'Média': [média_uruguay_depois,média_total_países_mercosul],
}
tabela_media_uruguayXmercosul = pd.DataFrame(data, columns=['País/Organização', 'Média'])
tabela_media_uruguayXmercosul
# Out:
#   País/Organização       Média
# 0          Uruguay  229.407407
# 1         Mercosul   76.926019

# %%
plot = tabela_media_uruguayXmercosul.plot(kind='bar',title='Exportação Uruguay X mercosul',figsize=(6, 6),color=('g','g'))
plt.ylabel('Exportação (em % do Pib)')
plt.xlabel('Uruguay X Mercosul')
plt.show()

# %%
plt.scatter(uruguay_depois.index,uruguay_depois, color="r")
plt.scatter(exportacao_paises_Mercosul.index ,média_paises_mercosul, color="b")
plt.title('Exportação Uruguay X Exportação Mercosul')
plt.xlabel('Ano')
plt.ylabel('Exportação')
# Out:
# Text(0, 0.5, 'Exportação')

# %% [markdown]
# Outros Países

# %%
exportacao_invertida=exportacao_indice.transpose()
exportacao_invertida
# Out:
# country  Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  \
# 1960            4.13      NaN     39.0     NaN                  NaN
# 1961            4.45      NaN     46.2     NaN                  NaN
# 1962            4.88      NaN     19.8     NaN                  NaN
# 1963            9.17      NaN     24.7     NaN                  NaN
# 1964            8.89      NaN     25.1     NaN                  NaN
# 1965           11.30      NaN     22.6     NaN                  NaN
# 1966            8.57      NaN     26.0     NaN                  NaN
# 1967            6.77      NaN     23.4     NaN                  NaN
# 1968            8.90      NaN     23.1     NaN                  NaN
# 1969           10.10      NaN     23.8     NaN                  NaN
# 1970            9.78      NaN     22.1     NaN                  NaN
# 1971           10.90      NaN     18.4     NaN                  NaN
# 1972           14.80      NaN     20.4     NaN                  NaN
# 1973           12.90      NaN     25.5     NaN                  NaN
# 1974           14.00      NaN     38.7     NaN                  NaN
# 1975           12.70      NaN     33.7     NaN                  NaN
# 1976           13.20      NaN     33.1     NaN                  NaN
# 1977           11.70      NaN     30.6     NaN                 40.7
# 1978           10.80      NaN     25.5     NaN                 52.5
# 1979             NaN      NaN     31.1     NaN                 69.2
# 1980             NaN    23.10     34.3     NaN                 56.4
# 1981             NaN    23.00     34.6     NaN                 61.6
# 1982             NaN    19.40     30.9     NaN                 56.9
# 1983             NaN    18.20     27.9     NaN                 51.6
# 1984             NaN    17.40     25.7     NaN                 62.2
# 1985             NaN    16.20     23.6    44.2                 63.0
# 1986             NaN    15.10     12.9    47.3                 70.9
# 1987             NaN    15.50     14.3    41.3                 67.3
# 1988             NaN    16.40     15.5    38.1                 66.6
# 1989             NaN    17.90     18.6    32.8                 66.3
# 1990             NaN    14.90     23.4    29.8                 75.2
# 1991             NaN     7.22     29.1    28.6                 76.8
# 1992             NaN    11.50     25.3    47.4                 81.6
# 1993             NaN    15.40     21.8    49.3                 82.1
# 1994             NaN    11.40     22.5     NaN                 74.0
# 1995             NaN    12.50     26.2     NaN                 69.6
# 1996             NaN    11.20     29.8     NaN                 63.5
# 1997             NaN     9.75     30.9     NaN                 65.1
# 1998             NaN    10.80     22.6     NaN                 64.0
# 1999             NaN    15.80     28.2     NaN                 61.7
# 2000             NaN    17.90     42.1    89.7                 56.2
# 2001             NaN    18.40     36.7    75.4                 55.6
# 2002           32.40    19.60     35.5    68.3                 52.5
# 2003           43.60    20.40     38.2    68.4                 54.1
# 2004           34.00    22.00     40.1    70.3                 58.1
# 2005           27.40    22.80     47.2    86.0                 53.3
# 2006           26.50    24.90     48.8    79.8                 47.4
# 2007           17.80    28.10     47.1    74.0                 44.3
# 2008           18.00    25.30     48.0    76.3                 45.7
# 2009           14.70    25.20     35.4    54.9                 45.9
# 2010           10.00    28.00     38.4    62.3                 45.5
# 2011            6.11    29.20     38.8    65.4                 47.1
# 2012            5.52    28.90     36.9    63.1                 44.9
# 2013            6.31    28.90     33.2    55.7                 45.7
# 2014            6.57    28.20     30.2    48.0                 46.1
# 2015            7.00    27.30     23.2    33.4                 44.1
# 2016            6.90    28.90     21.0    30.0                 41.7
# 2017             NaN    31.50     24.0    29.9                  NaN
#
# country  Argentina  Armenia  Australia  Austria  Azerbaijan  ...  \
# 1960          7.60      NaN       13.0     23.2         NaN  ...
# 1961          5.99      NaN       12.4     23.0         NaN  ...
# 1962          4.69      NaN       13.9     23.4         NaN  ...
# 1963          7.89      NaN       13.0     23.4         NaN  ...
# 1964          5.56      NaN       14.9     23.4         NaN  ...
# 1965          6.23      NaN       13.2     23.8         NaN  ...
# 1966          6.65      NaN       12.9     23.7         NaN  ...
# 1967          7.50      NaN       12.9     23.7         NaN  ...
# 1968          6.48      NaN       12.3     24.3         NaN  ...
# 1969          6.40      NaN       12.0     26.8         NaN  ...
# 1970          5.60      NaN       13.0     27.4         NaN  ...
# 1971          6.01      NaN       12.7     27.0         NaN  ...
# 1972          7.20      NaN       12.8     26.9         NaN  ...
# 1973          7.61      NaN       14.2     26.9         NaN  ...
# 1974          6.90      NaN       13.2     29.1         NaN  ...
# 1975          5.82      NaN       14.3     28.1         NaN  ...
# 1976          9.18      NaN       13.5     28.8         NaN  ...
# 1977          9.62      NaN       14.0     28.0         NaN  ...
# 1978          8.61      NaN       13.6     29.1         NaN  ...
# 1979          6.51      NaN       14.3     30.9         NaN  ...
# 1980          5.06      NaN       16.4     31.7         NaN  ...
# 1981          6.92      NaN       14.9     33.0         NaN  ...
# 1982          9.09      NaN       13.5     31.7         NaN  ...
# 1983          9.15      NaN       13.6     30.5         NaN  ...
# 1984          7.59      NaN       13.6     32.8         NaN  ...
# 1985         11.70      NaN       15.3     34.9         NaN  ...
# 1986          8.16      NaN       15.0     32.0         NaN  ...
# 1987          7.87      NaN       15.5     31.4         NaN  ...
# 1988          9.53      NaN       16.0     33.1         NaN  ...
# 1989         13.10      NaN       15.1     35.0         NaN  ...
# 1990         10.40     35.0       15.1     35.7        43.9  ...
# 1991          7.68     40.7       16.1     34.6        45.7  ...
# 1992          6.60     39.8       16.7     33.2        86.2  ...
# 1993          6.91     47.2       17.6     31.5        57.4  ...
# 1994          7.53     39.3       18.0     32.2        24.7  ...
# 1995          9.68     23.9       17.9     33.5        27.9  ...
# 1996         10.40     23.2       18.9     34.2        29.5  ...
# 1997         10.60     20.3       19.2     37.0        29.0  ...
# 1998         10.40     19.0       19.6     38.4        22.7  ...
# 1999          9.83     20.8       18.4     39.4        28.0  ...
# 2000         11.00     23.4       19.4     43.3        39.0  ...
# 2001         11.60     25.5       22.2     44.6        40.9  ...
# 2002         28.40     29.4       20.8     45.3        42.8  ...
# 2003         25.90     32.2       19.1     44.6        42.0  ...
# 2004         23.80     29.7       17.2     46.9        48.8  ...
# 2005         23.20     28.8       18.3     48.6        62.9  ...
# 2006         23.00     23.4       19.9     50.8        66.5  ...
# 2007         22.70     19.2       20.2     52.6        68.1  ...
# 2008         22.10     15.0       20.2     53.2        65.8  ...
# 2009         19.60     15.5       23.0     45.2        51.6  ...
# 2010         18.90     20.8       19.8     51.3        54.3  ...
# 2011         18.40     23.8       21.5     53.9        56.4  ...
# 2012         16.20     27.6       21.5     54.0        53.0  ...
# 2013         14.60     28.4       20.0     53.4        48.3  ...
# 2014         14.40     28.6       21.1     53.4        43.3  ...
# 2015         10.70     29.7       20.0     52.9        37.8  ...
# 2016         12.60     33.1       19.3     52.3        46.4  ...
# 2017         11.20     38.1       21.3     53.9        48.7  ...
#
# country  United Kingdom  United States  Uruguay  Uzbekistan  Vanuatu  \
# 1960              202.0          497.0    138.0         NaN      NaN
# 1961              199.0          490.0    142.0         NaN      NaN
# 1962              194.0          481.0    113.0         NaN      NaN
# 1963              193.0          487.0    120.0         NaN      NaN
# 1964              187.0          510.0    119.0         NaN      NaN
# 1965              185.0          499.0    184.0         NaN      NaN
# 1960          13.0     23.2         NaN      NaN  ...                   NaN
# 1961          12.4     23.0         NaN      NaN  ...                   NaN
# 1962          13.9     23.4         NaN      NaN  ...                   NaN
# 1963          13.0     23.4         NaN      NaN  ...                   NaN
# 1964          14.9     23.4         NaN      NaN  ...                   NaN
# 1965          13.2     23.8         NaN      NaN  ...                   NaN
# 1966          12.9     23.7         NaN      NaN  ...                   NaN
# 1967          12.9     23.7         NaN      NaN  ...                   NaN
# 1968          12.3     24.3         NaN      NaN  ...                   NaN
# 1969          12.0     26.8         NaN      NaN  ...                   NaN
# 1970          13.0     27.4         NaN      NaN  ...                   NaN
# 1971          12.7     27.0         NaN      NaN  ...                   NaN
# 1972          12.8     26.9         NaN      NaN  ...                   NaN
# 1973          14.2     26.9         NaN      NaN  ...                   NaN
# 1974          13.2     29.1         NaN      NaN  ...                   NaN
# 1975          14.3     28.1         NaN      NaN  ...                   NaN
# 1976          13.5     28.8         NaN      NaN  ...                   NaN
# 1977          14.0     28.0         NaN     82.7  ...                   NaN
# 1978          13.6     29.1         NaN     82.7  ...                   NaN
# 1979          14.3     30.9         NaN     68.9  ...                   NaN
# 1980          16.4     31.7         NaN     70.4  ...                   NaN
# 1981          14.9     33.0         NaN     67.4  ...                   NaN
# 1982          13.5     31.7         NaN     65.8  ...                   NaN
# 1983          13.6     30.5         NaN     66.6  ...                   NaN
# 1984          13.6     32.8         NaN     63.6  ...                   NaN
# 1985          15.3     34.9         NaN     64.8  ...                   NaN
# 1986          15.0     32.0         NaN     63.8  ...                   NaN
# 1987          15.5     31.4         NaN     61.3  ...                   NaN
# 1988          16.0     33.1         NaN      NaN  ...                   NaN
# 1989          15.1     35.0         NaN     53.8  ...                   NaN
# 1990          15.1     35.7        43.9     54.2  ...                   NaN
# 1991          16.1     34.6        45.7     51.0  ...                   NaN
# 1992          16.7     33.2        86.2     50.2  ...                   NaN
# 1993          17.6     31.5        57.4     52.0  ...                   NaN
# 1994          18.0     32.2        24.7     51.0  ...                   NaN
# 1995          17.9     33.5        27.9     49.5  ...                   NaN
# 1996          18.9     34.2        29.5     48.0  ...                   NaN
# 1997          19.2     37.0        29.0     36.9  ...                   NaN
# 1998          19.6     38.4        22.7     34.7  ...                   NaN
# 1999          18.4     39.4        28.0     36.5  ...                   NaN
# 2000          19.4     43.3        39.0     38.0  ...                   NaN
# 2001          22.2     44.6        40.9     34.1  ...                 492.0
# 2002          20.8     45.3        42.8     36.2  ...                 495.0
# 2003          19.1     44.6        42.0     35.8  ...                 559.0
# 2004          17.2     46.9        48.8     38.2  ...                 636.0
# 2005          18.3     48.6        62.9     38.8  ...                 676.0
# 2006          19.9     50.8        66.5     38.3  ...                 686.0
# 2007          20.2     52.6        68.1     40.1  ...                 724.0
# 2008          20.2     53.2        65.8     39.5  ...                 789.0
# 2009          23.0     45.2        51.6     34.2  ...                 797.0
# 2010          19.8     51.3        54.3     35.0  ...                 777.0
# 2011          21.5     53.9        56.4     37.4  ...                 898.0
# 2012          21.5     54.0        53.0     38.1  ...                 100.0
# 2013          20.0     53.4        48.3     39.9  ...                 101.0
# 2017              305.0            NaN       285.0      NaN        NaN
#
# country  Vietnam  Yemen  Zambia  Zimbabwe
# 1960         NaN    NaN     NaN       NaN
# 1961         NaN    NaN     NaN       NaN
# 1962         NaN    NaN     NaN       NaN
# 1963         NaN    NaN     NaN       NaN
# 1964         NaN    NaN     NaN       NaN
# 1965         NaN    NaN     NaN       NaN
# 1966         NaN    NaN     NaN       NaN
# 1967         NaN    NaN     NaN       NaN
# 1968         NaN    NaN     NaN       NaN
# 1969         NaN    NaN     NaN       NaN
# 1970         NaN    NaN     NaN       NaN
# 1971         NaN    NaN     NaN       NaN
# 1972         NaN    NaN     NaN       NaN
# 1973         NaN    NaN     NaN       NaN
# 1974         NaN    NaN     NaN       NaN
# 1975         NaN    NaN     NaN     228.0
# 1976         NaN    NaN     NaN     220.0
# 1977         NaN    NaN     NaN     214.0
# 1978         NaN    NaN     NaN     220.0
# 1979         NaN    NaN     NaN     218.0
# 1980         NaN    NaN     NaN     234.0
# 1981         NaN    NaN     NaN     194.0
# 1982         NaN    NaN     NaN     169.0
# 1983         NaN    NaN     NaN     164.0
# 1984         NaN    NaN     NaN     206.0
# 1985         NaN    NaN     NaN     222.0
# 1986       662.0    NaN     NaN     240.0
# 1987       600.0    NaN     NaN     240.0
# 1988       395.0    NaN     NaN     237.0
# 1989       238.0    NaN     NaN     233.0
# 1990       360.0  122.0     NaN     229.0
# 1991       309.0  110.0     NaN     239.0
# 1992       347.0  104.0     NaN     272.0
# 1993       287.0  126.0     NaN     307.0
# 1994       340.0  125.0   330.0     346.0
# 1995       328.0  224.0   329.0     382.0
# 1996       409.0  385.0   285.0     361.0
# 1997       431.0  363.0   274.0     376.0
# 1998       448.0  265.0   246.0     434.0
# 1999       500.0  348.0   250.0     374.0
# 2000       539.0  414.0   239.0     382.0
# 2001       551.0  359.0   251.0     350.0
# 2002       547.0  370.0   271.0     318.0
# 2003       567.0  364.0   257.0     324.0
# 2004       597.0  364.0   335.0     345.0
# 2005       637.0  409.0   306.0     335.0
# 2006       677.0  413.0   326.0     360.0
# 2007       705.0  359.0   336.0     378.0
# 2008       703.0  378.0   289.0     415.0
# 2009       626.0  283.0   293.0     218.0
# 2010       720.0  300.0   370.0     352.0
# 2011       794.0  303.0   405.0     406.0
# 2012       800.0  249.0   401.0     302.0
# 2013       836.0  224.0   405.0     272.0
# 2014       864.0  215.0   388.0     257.0
# 2015       898.0  109.0   371.0     235.0
# 2016       936.0  358.0   353.0     247.0
# 2017       102.0    NaN   352.0     241.0
#
# [58 rows x 181 columns]

# %%
medias_outros_paises_p_ano =exportacao_outros_paises.describe()
medias_outros_paises_p_ano
# Out:
# country  Afghanistan    Albania    Algeria     Angola  Antigua and Barbuda  \
# count      34.000000  38.000000  58.000000  27.000000            40.000000
# mean       13.257353  19.951842  29.581034  55.174074            58.175000
# std         9.252768   6.587504   8.807303  18.773090            11.469665
# min         4.130000   7.220000  12.900000  28.600000            40.700000
# 25%         6.925000  15.425000  23.250000  39.700000            46.850000
# 50%        10.450000  18.900000  28.050000  54.900000            56.650000
# 75%        14.525000  25.275000  35.475000  69.350000            66.375000
# max        43.600000  31.500000  48.800000  89.700000            82.100000
#
# country    Armenia  Australia    Austria  Azerbaijan    Bahamas  ...  \
# count    28.000000  58.000000  58.000000   28.000000  40.000000  ...
# mean     27.907143  16.505172  36.153448   46.842857  48.545000  ...
# std       8.057797   3.170225  10.347882   14.882414  14.431233  ...
# min      15.000000  12.000000  23.000000   22.700000  33.700000  ...
# 25%      22.600000  13.600000  28.025000   38.700000  36.800000  ...
# 50%      28.000000  15.750000  33.050000   46.050000  40.000000  ...
# 75%      32.425000  19.375000  45.050000   54.825000  61.875000  ...
# max      47.200000  23.000000  54.000000   86.200000  82.700000  ...
#
# country  United Arab Emirates  United Kingdom  United States  Uzbekistan  \
# count               17.000000       58.000000      57.000000   28.000000
# mean               530.764706      243.379310     543.578947  289.825000
# std                312.976742       32.182499     329.334770   86.416895
# min                100.000000      185.000000     100.000000   23.100000
# 25%                101.000000      219.000000     136.000000  261.000000
# 50%                636.000000      247.500000     539.000000  286.500000
# 75%                777.000000      267.750000     846.000000  356.000000
# max                991.000000      305.000000     986.000000  411.000000
#
# country     Vanuatu   Venezuela     Vietnam       Yemen      Zambia  \
# count     35.000000   55.000000   32.000000   27.000000   24.000000
# mean     438.342857  269.400000  554.781250  283.074074  319.250000
# std       55.474924   55.229018  209.626355  107.308658   53.903497
# min      332.000000  167.000000  102.000000  104.000000  239.000000
# 25%      400.000000  225.500000  386.250000  219.500000  273.250000
# 50%      446.000000  268.000000  559.000000  303.000000  327.500000
# 75%      468.500000  298.000000  703.500000  364.000000  357.250000
# max      577.000000  397.000000  936.000000  414.000000  405.000000
#
# country    Zimbabwe
# count     43.000000
# mean     285.953488
# std       73.502495
# min      164.000000
# 25%      228.500000
# 50%      257.000000
# 75%      351.000000
# max      434.000000
#
# [8 rows x 181 columns]

# %%
média_outros_paises=medias_outros_paises_p_ano.loc["mean",:]
média_total_outros_paises=média_outros_paises.mean()

# %%
data = {
'País/Organização': ['Uruguay', 'Outros paises'],
'Média': [média_uruguay_depois,média_total_outros_paises],
}
tabela_media_uruguayXoutro_paises = pd.DataFrame(data, columns=['País/Organização', 'Média'])

# %%
plot = tabela_media_uruguayXoutro_paises.plot(kind='bar',title='Exportação Uruguay X outros paises',figsize=(6, 6),color=('pink','pink'))
plt.ylabel('Exportação (em % do Pib)')
plt.xlabel('Uruguay X Outros Países')
plt.show()

# %%
data = {
'País/Organização': ['Uruguay', 'Mercosul','Outros países'],
'Média': [média_uruguay_depois,média_total_países_mercosul, média_total_outros_paises ],
}
tabela_media_uruguayXmercosulXoutros_paises = pd.DataFrame(data, columns=['País/Organização', 'Média'])

# %%
plot = tabela_media_uruguayXmercosulXoutros_paises.plot(kind='bar',title='Exportação Comparação',figsize=(6, 6),color=('red','red'))
plt.ylabel('Exportação (em % do Pib)')
plt.xlabel('Uruguay X Mercosul X Outros Países')
plt.show()

# %%
#tabela dos países semelhantes aos países do mercosul
#usar o PIB para encontrar países semelhantes

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Responda à pergunta, argumento da melhor forma possível com base nos dados
